# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('application_record.csv')

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['DAYS_EMPLOYED']
# Out:
# 0          -4542
# 1          -4542
# 2          -1134
# 3          -3051
# 4          -3051
#            ...
# 438552    365243
# 438553     -3007
# 438554      -372
# 438555    365243
# 438556     -1201
# Name: DAYS_EMPLOYED, Length: 438557, dtype: int64

# %%
df=df[df['DAYS_EMPLOYED'] <1]
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438547  6839917           F            N               Y             0
# 438548  6839936           M            Y               Y             1
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['DAYS_EMPLOYED']=df['DAYS_EMPLOYED']*-1

# %%
df['DAYS_EMPLOYED']
# Out:
# 0         4542
# 1         4542
# 2         1134
# 3         3051
# 4         3051
#           ...
# 438547    2704
# 438548    2095
# 438553    3007
# 438554     372
# 438556    1201
# Name: DAYS_EMPLOYED, Length: 363228, dtype: int64

# %%
df['DAYS_BIRTH']=df['DAYS_BIRTH']*-1

# %%
df['DAYS_BIRTH']
# Out:
# 0         12005
# 1         12005
# 2         21474
# 3         19110
# 4         19110
#           ...
# 438547    10966
# 438548    12569
# 438553    15939
# 438554     8169
# 438556    18858
# Name: DAYS_BIRTH, Length: 363228, dtype: int64

# %%
sns.scatterplot(data=df,x='DAYS_BIRTH',y='DAYS_EMPLOYED')
# Out:
# <Axes: xlabel='DAYS_BIRTH', ylabel='DAYS_EMPLOYED'>

# %%
df['DAYS_BIRTH']
# Out:
# 0         12005
# 1         12005
# 2         21474
# 3         19110
# 4         19110
#           ...
# 438547    10966
# 438548    12569
# 438553    15939
# 438554     8169
# 438556    18858
# Name: DAYS_BIRTH, Length: 363228, dtype: int64

# %%
import warnings
warnings.simplefilter('ignore')
df['years']=df['DAYS_BIRTH']/365*-1

# %%
sns.histplot(data=df,x='years',bins=45,color='pink')
# Out:
# <Axes: xlabel='years', ylabel='Count'>

# %%
int(len(df)/2)
# Out:
# 181614

# %%
bottom=df.nsmallest(n=181614,columns='AMT_INCOME_TOTAL')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=bottom,x='NAME_FAMILY_STATUS',y='AMT_INCOME_TOTAL',hue='FLAG_OWN_REALTY')
# Out:
# <Axes: xlabel='NAME_FAMILY_STATUS', ylabel='AMT_INCOME_TOTAL'>

# %%
sns.heatmap(data=df,lw=0.6,annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[218], line 1
# ----> 1 sns.heatmap(data=df,lw=0.6,annot=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
# ...

# %%
sns.heatmap(data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 sns.heatmap(data=df)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...
