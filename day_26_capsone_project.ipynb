# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('fandango_scrape.csv')

# %%
df2=pd.read_csv('all_sites_scores.csv')

# %%
df1
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 499                      Valiyavan (2015)    0.0     0.0      0
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 503                         Zarafa (2012)    0.0     0.0      0
#
# [504 rows x 4 columns]

# %%
df2
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
# plt.figure(figsize=(12,6))
sns.scatterplot(data=df1,x='RATING',y='VOTES',alpha=0.4,color='red',s=100)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
pd1.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 pd1.corr()
#
# NameError: name 'pd1' is not defined

# %%
df1['YEAR']=df1['FILM'].apply(lambda year: year.split('(')[-1].replace(')',''))

# %%
df1
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
sns.countplot(data=df1,x='YEAR')
# Out:
# <Axes: xlabel='YEAR', ylabel='count'>

# %%
df1.sort_values('VOTES',ascending=False)[:10]
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
df1.nlargest(10,'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
sum(df1[df1['VOTES']==0].value_counts())
# Out:
# 69

# %%
f=df1[df1['VOTES']>0]

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(data=fan_review,x='RATING',fill=True,label='True rating',clip=(0,5))
sns.kdeplot(data=fan_review,x='STARS',fill=True,label='True stars',clip=(0,5))
plt.legend(loc=0)

# %%
f['RATING_DIFF']=round(f['STARS']-f['RATING'],2)
# Out:
# C:\Users\FAISAL\AppData\Local\Temp\ipykernel_4676\1700847548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['RATING_DIFF']=round(f['STARS']-f['RATING'],2)

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=f,x='RATING_DIFF',palette='magma')
# Out:
# C:\Users\FAISAL\AppData\Local\Temp\ipykernel_4676\274584226.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=f,x='RATING_DIFF',palette='magma')
# <Axes: xlabel='RATING_DIFF', ylabel='count'>

# %%
f[f['RATING_DIFF']==1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  RATING_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015          1.0

# %%
df2=pd.read_csv('all_sites_scores.csv')

# %%
df2
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.3+ KB

# %%
df2.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
sns.scatterplot(data=df2,x='RottenTomatoes',y='RottenTomatoes_User')
# Out:
# <Axes: xlabel='RottenTomatoes', ylabel='RottenTomatoes_User'>

# %%
df2['CRITICS_DIFF']=df2['RottenTomatoes']-df2['RottenTomatoes_User']

# %%
df2
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
ABSOLUTE=df2['CRITICS_DIFF'].apply(abs)

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df2,x='CRITICS_DIFF',kde=True,bins=25)
# Out:
# <Axes: xlabel='CRITICS_DIFF', ylabel='Count'>

# %%
df2
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
sns.histplot(x=df2['CRITICS_DIFF'].apply(abs),bins=25,kde=True)
# Out:
# <Axes: xlabel='CRITICS_DIFF', ylabel='Count'>

# %%
df2.nsmallest(5,'CRITICS_DIFF')[['FILM','RottenTomatoes']]
# Out:
#                           FILM  RottenTomatoes
# 3       Do You Believe? (2015)              18
# 85           Little Boy (2015)              20
# 105    Hitman: Agent 47 (2015)               7
# 134    The Longest Ride (2015)              31
# 125  The Wedding Ringer (2015)              27

# %%
df2.nlargest(5,'CRITICS_DIFF')[['FILM','RottenTomatoes']]
# Out:
#                                  FILM  RottenTomatoes
# 69                  Mr. Turner (2014)              98
# 112                 It Follows (2015)              96
# 115          While We're Young (2015)              83
# 37               Welcome to Me (2015)              71
# 40   I'll See You In My Dreams (2015)              94

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(data=df2,x='Metacritic',y='Metacritic_User',)
# Out:
# <Axes: xlabel='Metacritic', ylabel='Metacritic_User'>

# %%
sns.scatterplot(data=df2,x='Metacritic_user_vote_count',y='IMDB_user_vote_count')
# Out:
# <Axes: xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %%
df2.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  CRITICS_DIFF  ABSOLUTE
# 14                334164            -2  15.09589

# %%
df2.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  CRITICS_DIFF  ABSOLUTE
# 88                292023             9  15.09589

# %%
df=pd.merge(df1,df2,on='FILM',how='inner')

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  CRITICS_DIFF                145 non-null    int64
# ...

# %%
df['RT_NORM']=np.round(df['RottenTomatoes']/20,1)
df['RTU_NORM']=np.round(df['RottenTomatoes_User']/20,1)
df['MT_NORM']=np.round(df['Metacritic']/20,1)
df['MTU_NORM']=np.round(df['Metacritic_User']/2,1)
df['IBM_NORM']=np.round(df['IMDB']/2,1)

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'CRITICS_DIFF',
#        'ABSOLUTE', 'RT_NORM', 'RTU_NORM', 'MT_NORM', 'MTU_NORM', 'IBM_NORM'],
#       dtype='object')

# %%
norm_scores=df[['STARS', 'RATING','RT_NORM', 'RTU_NORM', 'MT_NORM', 'MTU_NORM', 'IBM_NORM']]

# %%
norm_scores
# Out:
#      STARS  RATING  RT_NORM  RTU_NORM  MT_NORM  MTU_NORM  IBM_NORM
# 0      4.0     3.9      1.2       2.1      2.3       1.6       2.1
# 1      4.5     4.5      3.6       4.0      3.0       3.5       3.6
# 2      5.0     4.8      3.6       4.2      3.6       3.3       3.7
# 3      5.0     4.8      4.0       4.2      3.4       3.4       3.7
# 4      4.5     4.5      4.9       4.5      4.7       4.4       4.3
# ..     ...     ...      ...       ...      ...       ...       ...
# 140    3.5     3.5      4.4       3.2      3.4       3.2       3.4
# 141    4.0     3.6      4.8       4.0      4.4       3.2       3.5
# 142    4.5     4.2      4.6       4.2      3.4       3.5       3.9
# 143    4.0     3.9      4.8       4.3      4.3       3.6       3.7
# 144    3.5     3.1      3.0       2.3      3.4       2.9       3.2
#
# [145 rows x 7 columns]

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.kdeplot(data=norm_scores,fill=True,palette='Set1',clip=(0,5))
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.kdeplot(data=norm_scores[['RT_NORM','STARS']],fill=True,palette='Set1',clip=(0,5))
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(data=norm_scores)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.clustermap(data=norm_scores,cmap='magma',col_cluster=False)

# %%
norm_scores.columns
# Out:
# Index(['STARS', 'RATING', 'RT_NORM', 'RTU_NORM', 'MT_NORM', 'MTU_NORM',
#        'IBM_NORM'],
#       dtype='object')

# %%
norm_film=df[['STARS', 'RATING', 'RT_NORM', 'RTU_NORM', 'MT_NORM', 'MTU_NORM',
       'IBM_NORM']]

# %%
norm_film
# Out:
#      STARS  RATING  RT_NORM  RTU_NORM  MT_NORM  MTU_NORM  IBM_NORM
# 0      4.0     3.9      1.2       2.1      2.3       1.6       2.1
# 1      4.5     4.5      3.6       4.0      3.0       3.5       3.6
# 2      5.0     4.8      3.6       4.2      3.6       3.3       3.7
# 3      5.0     4.8      4.0       4.2      3.4       3.4       3.7
# 4      4.5     4.5      4.9       4.5      4.7       4.4       4.3
# ..     ...     ...      ...       ...      ...       ...       ...
# 140    3.5     3.5      4.4       3.2      3.4       3.2       3.4
# 141    4.0     3.6      4.8       4.0      4.4       3.2       3.5
# 142    4.5     4.2      4.6       4.2      3.4       3.5       3.9
# 143    4.0     3.9      4.8       4.3      4.3       3.6       3.7
# 144    3.5     3.1      3.0       2.3      3.4       2.9       3.2
#
# [145 rows x 7 columns]

# %%
worst_film=norm_film.nsmallest(10,'RT_NORM')

# %%
plt.figure(figsize=(15,6),dpi=300)
sns.kdeplot(data=worst_film,fill=True)
# Out:
# <Axes: ylabel='Density'>
