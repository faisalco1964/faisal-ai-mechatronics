# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('hotel_booking_data.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.shape[0]
# Out:
# 119390

# %%
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df=df.drop('company',axis=1)

# %%
df.groupby('country').count().sort_values('hotel',ascending=False)['hotel'][:5]
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# Name: hotel, dtype: int64

# %%
df['country'].value_counts()[:5]
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# Name: count, dtype: int64

# %%
df.sort_values('adr',ascending=False)[['adr','name']].iloc[0]
# Out:
# adr            5400.0
# name    Daniel Walter
# Name: 48515, dtype: object

# %%
df['adr'].idxmax()
# Out:
# 48515

# %%
df.iloc[48515]
# Out:
# hotel                                             City Hotel
# is_canceled                                                1
# lead_time                                                 35
# arrival_date_year                                       2016
# arrival_date_month                                     March
# arrival_date_week_number                                  13
# arrival_date_day_of_month                                 25
# stays_in_weekend_nights                                    0
# stays_in_week_nights                                       1
# adults                                                     2
# children                                                 0.0
# babies                                                     0
# meal                                                      BB
# country                                                  PRT
# market_segment                                 Offline TA/TO
# ...

# %%
round(df['adr'].mean(numeric_only=True),2)
# Out:
# np.float64(101.83)

# %%
for col in df.columns:
      print(col)
# Out:
# hotel
# is_canceled
# lead_time
# arrival_date_year
# arrival_date_month
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# meal
# country
# market_segment
# distribution_channel
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# reserved_room_type
# assigned_room_type
# booking_changes
# deposit_type
# agent
# company
# days_in_waiting_list
# customer_type
# adr
# required_car_parking_spaces
# total_of_special_requests
# reservation_status
# reservation_status_date
# name
# email
# phone-number
# credit_card

# %%
df['stays_in_week_nights'].mean()
# Out:
# np.float64(2.500301532791691)

# %%
df['stays_in_weekend_nights'].mean()
# Out:
# np.float64(0.9275986263506156)

# %%
df['number_of_night_stayed']=df['stays_in_week_nights'].mean()+df['stays_in_weekend_nights'].mean()

# %%
round(df['number_of_night_stayed'].iloc[0],2)
# Out:
# np.float64(3.43)

# %%
df['number_of_night_stayed']=df['stays_in_week_nights']+df['stays_in_weekend_nights']

# %%
round(df['number_of_night_stayed'].mean(),2)
# Out:
# np.float64(3.43)

# %%
df['total_spend']=df['adr']*df['number_of_night_stayed']

# %%
df['total_spend'].mean()
# Out:
# np.float64(357.84820780634897)

# %%
df[df['total_of_special_requests']==5][['name','email']]
# Out:
#                           name                          email
# 7860             Amanda Harper           Amanda.H66@yahoo.com
# 11125            Laura Sanders      Sanders_Laura@hotmail.com
# 14596              Tommy Ortiz            Tommy_O@hotmail.com
# 14921           Gilbert Miller         Miller.Gilbert@aol.com
# 14922           Timothy Torres         TTorres@protonmail.com
# 24630          Jennifer Weaver             Jennifer_W@aol.com
# 27288           Crystal Horton             Crystal.H@mail.com
# 27477           Brittney Burke       Burke_Brittney16@att.com
# 29906          Cynthia Cabrera    Cabrera.Cynthia@xfinity.com
# 29949              Sarah Floyd              Sarah_F@gmail.com
# 32267           Michelle Villa         Michelle.Villa@aol.com
# 39027           Nichole Hebert       Hebert.Nichole@gmail.com
# 39129         Lindsey Mckenzie       Lindsey.Mckenzie@att.com
# 39525           Ashley Edwards       Edwards.Ashley@yahoo.com
# ...

# %%
sum(df['is_repeated_guest']==1)
# Out:
# 3810

# %%
sum(df['is_repeated_guest']==1)/len(df)
# Out:
# 0.03191222045397437

# %%
sum(df['is_repeated_guest']==1)/len(df)*100
# Out:
# 3.191222045397437

# %%
df['name'].apply(lambda name:name.split())
# Out:
# 0               [Ernest, Barnes]
# 1                [Andrea, Baker]
# 2              [Rebecca, Parker]
# 3                [Laura, Murray]
# 4                 [Linda, Hines]
#                    ...
# 119385        [Claudia, Johnson]
# 119386         [Wesley, Aguilar]
# 119387           [Mary, Morales]
# 119388    [Caroline, Conley, MD]
# 119389         [Ariana, Michael]
# Name: name, Length: 119390, dtype: object

# %%
df['name'].apply(lambda name:name.split()[1])
# Out:
# 0          Barnes
# 1           Baker
# 2          Parker
# 3          Murray
# 4           Hines
#            ...
# 119385    Johnson
# 119386    Aguilar
# 119387    Morales
# 119388     Conley
# 119389    Michael
# Name: name, Length: 119390, dtype: object

# %%
def last(name):
    name=name.split()[1]
    return name
name='faisal ibrahim'
last(name)
# Out:
# 'ibrahim'

# %%
df['name'].apply(last)
# Out:
# 0          Barnes
# 1           Baker
# 2          Parker
# 3          Murray
# 4           Hines
#            ...
# 119385    Johnson
# 119386    Aguilar
# 119387    Morales
# 119388     Conley
# 119389    Michael
# Name: name, Length: 119390, dtype: object

# %%
df['total_kids']=df['children']+df['babies']
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.sort_values('total_kids',ascending=False)['name']
# Out:
# 328         Jamie Ramirez
# 46619     Nicholas Parker
# 78656       Marc Robinson
# 6681       Nicolas Thomas
# 16360         Ashley Cole
#                ...
# 119389     Ariana Michael
# 40600        Craig Campos
# 40667        David Murphy
# 40679        Frank Burton
# 41160       Jerry Roberts
# Name: name, Length: 119390, dtype: object

# %%
def area(code):
    code =int(str(code)[:3])
    return code
code = 345678
area(code)
# Out:
# 345

# %%
df['area_code']=df['phone-number'].apply(area)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df['area_code'].value_counts()
# Out:
# area_code
# 799    168
# 185    167
# 541    166
# 137    163
# 763    163
#       ...
# 896    106
# 973    105
# 577    105
# 818    102
# 970     97
# Name: count, Length: 900, dtype: int64

# %%
df['phone-number'].apply(lambda num: num[:3]).value_counts()
# Out:
# phone-number
# 799    168
# 185    167
# 541    166
# 137    163
# 763    163
#       ...
# 896    106
# 973    105
# 577    105
# 818    102
# 970     97
# Name: count, Length: 900, dtype: int64

# %%
df['arrival_date_day_of_month'].apply(lambda day:day in range(1,16)).sum()
# Out:
# np.int64(58152)
