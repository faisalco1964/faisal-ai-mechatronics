# %%
import numpy as np 
import pandas as pd
import time

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
import timeit
setup ='''
import numpy as np
import pandas as pd
pd =pd.read_csv('tip.csv')
def cal(total_bill,tip):
    if tip/total >0.25:
       return 'high'
    else:
        return 'low'
'''

# %%
stm1 = '''
     df[['total_bill','tip']].apply(lambda df: cal(df['total_bill'],['tip']),axis =1)
'''
stm2 ='''
    np.vectorize(calc)(df['total_bill'],df['tip'])
'''

# %% [markdown]
# timeit.timeit(setup=setup,stmt=stm1,number=1000)

# %%
timeit.timeit(setup=setup,stmt=stm2,number=1000)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[83], line 1
#     timeit.timeit(setup=setup,stmt=stm2,number=1000)
#
#   File ~\AppData\Local\Programs\Python\Python313\Lib\timeit.py:237 in timeit
#     return Timer(stmt, setup, timer, globals).timeit(number)
#
#   File ~\AppData\Local\Programs\Python\Python313\Lib\timeit.py:113 in __init__
#     compile(setup, dummy_src_name, "exec")
#
#   File <timeit-src>:6
#     if tip/total >0.25
#                       ^
# SyntaxError: expected ':'

# %%
df =pd.read_csv('tips.csv')
df
df.sort_values(['total_bill','tip','sex','day','time','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51   2.00    Male     No  Thur   Lunch     2              3.76
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#           Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].max()
# Out:
# np.float64(50.81)

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df['total_bill'].min()
# Out:
# np.float64(3.07)

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
df =pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
len(df['day'].value_counts())
# Out:
# 4

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique()
# Out:
# 4

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex'].replace(['Female','Male'],['F','M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
mymap = {'Female':'F','Male':'M'}
df['sex'].map(mymap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# # df.duplicated()

# %%
df1 = pd.DataFrame([3,4,5,6,6,6],['a','b','c','d','e','f'])
df1
# Out:
#    0
# a  3
# b  4
# c  5
# d  6
# e  6
# f  6

# %%
df1.duplicated()
# Out:
# a    False
# b    False
# c    False
# d    False
# e     True
# f     True
# dtype: bool

# %%
df1.drop_duplicates()
# Out:
#    0
# a  3
# b  4
# c  5
# d  6

# %%
df['total_bill'].between(10,20 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['total_bill'].between(10,20 )
#
# NameError: name 'df' is not defined

# %%
df.nlargest(2,'sex')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.nlargest(2,'sex')
#
# NameError: name 'df' is not defined

# %%
df.sort_values('tip',ascending =False).iloc[0:2]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %%
df.sort_values('tip',ascending =True).iloc[0:2]
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
#
#        Payer Name         CC Number Payment ID
# 92   Leah Ramirez  3508911676966392    Fri3780
# 111   Terri Jones  3559221007826887    Sat4801

# %%
df.nsmallest(2,'tip')
# Out:
#     total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92        5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
#
#        Payer Name         CC Number Payment ID
# 67  Tiffany Brock  4359488526995267    Sat3455
# 92   Leah Ramirez  3508911676966392    Fri3780

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 18        16.97  3.50  Female     No   Sun  Dinner     3              5.66
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3             14.77
# 156       48.17  5.00    Male     No   Sun  Dinner     6              8.03
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 123       15.95  2.00    Male     No  Thur   Lunch     2              7.98
#
#            Payer Name         CC Number Payment ID
# 18     Laura Martinez    30422275171379    Sun2789
# 102     Heather Cohen   379771118886604    Sat6240
# 156     Ryan Gonzales  3523151482063321    Sun7518
# 172       Larry White    30432617123103    Sun9209
# 123  Christopher Lang  4820629318698319   Thur1992

# %%
df.sample(frac=0.2)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 157       25.00  3.75  Female     No   Sun  Dinner     4              6.25
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 106       20.49  4.06    Male    Yes   Sat  Dinner     2             10.24
# 29        19.65  3.00  Female     No   Sat  Dinner     2              9.82
# 126        8.52  1.48    Male     No  Thur   Lunch     2              4.26
# 43         9.68  1.32    Male     No   Sun  Dinner     2              4.84
# 37        16.93  3.07  Female     No   Sat  Dinner     3              5.64
# 35        24.06  3.60    Male     No   Sat  Dinner     3              8.02
# 140       17.47  3.50  Female     No  Thur   Lunch     2              8.74
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5              5.63
# ...
